# %%
# !curl -X POST <CHATTERBOX_ENDPOINT>/voices \
  -H "Authorization: Bearer <CHATTERBOX_API_TOKEN>" \
  -F "voice_name=japanese_speaker" \
  -F "language=ja" \
  -F "voice_file=@meian_0000.wav"
# Out:
# {"message":"Voice uploaded successfully","voice":{"name":"japanese_speaker","filename":"japanese_speaker.wav","file_size":773578,"upload_date":"2025-11-26T14:25:38.295625","language":"ja"}}

# %%
# !curl -X POST <CHATTERBOX_ENDPOINT>/voices \
  -H "Authorization: Bearer <CHATTERBOX_API_TOKEN>" \
  -F "voice_name=french_speaker" \
  -F "language=fr" \
  -F "voice_file=@lupincontresholme_0009.wav"
# Out:
# {"message":"Voice uploaded successfully","voice":{"name":"french_speaker","filename":"french_speaker.wav","file_size":824618,"upload_date":"2025-11-26T14:25:39.872279","language":"fr"}}

# %%
# !curl -X POST <CHATTERBOX_ENDPOINT>/voices \
  -H "Authorization: Bearer <CHATTERBOX_API_TOKEN>" \
  -F "voice_name=arabic_speaker" \
  -F "language=ar" \
  -F "voice_file=@ARA_NORM_0002.wav"
# Out:
# {"message":"Voice uploaded successfully","voice":{"name":"arabic_speaker","filename":"arabic_speaker.wav","file_size":1479972,"upload_date":"2025-11-26T14:25:41.129806","language":"ar"}}
