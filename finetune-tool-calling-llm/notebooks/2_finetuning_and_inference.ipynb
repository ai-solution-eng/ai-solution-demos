# %% [markdown]
# # Part II: LoRA Fine-tuning Using NeMo Customizer
#
# This notebook covers the following:
#
# 0. [Prerequisites: Configurations, Health Checks, and Namespaces](#step-0)
# 1. [Upload Data to NeMo Datastore](#step-1)
# 2. [LoRA Customization with NeMo Customizer](#step-2)
# 3. [Running Inference on the Customized Model with NVIDIA NIM](#step-3)

# %%
# PCAI Setup — run this cell first after pip install + kernel restart
from pcai_setup import *
print('Ready')
# Out:
# PCAI setup complete
#   NeMo URL:  https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net
#   NIM URL:   https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net
#   Data Store (internal): http://nemo-data-store.nemo-microservices-25121.svc.cluster.local:3000
#   SSL verification: disabled
# Ready

# %%
import os
import json
import random
import requests
from openai import OpenAI
from nemo_microservices import NeMoMicroservices

# %% [markdown]
# <a id="step-0"></a>
# ## Prerequisites: Configurations, Health Checks, and Namespaces

# %% [markdown]
# Before you proceed, make sure that you completed the first notebook on data preparation to obtain the assets required to follow along.

# %% [markdown]
# ### Configure NeMo Microservices Endpoints

# %% [markdown]
# This section includes importing required libraries, configuring endpoints, and performing health checks to ensure that the NeMo Data Store, NIM, and other services are running correctly.

# %%
# Config and client already initialized via pcai_setup.py
# If you haven't run the setup cell above, run it first.
from config import *
from pcai_setup import nemo_client, hf_api

# %%
print(f"Single Endpoint for Data Store, Entity Store, Customizer, Evaluator, and NIM: {NEMO_URL}")
print(f"Namespace: {NMS_NAMESPACE}")
print(f"Base Model for Customization: {BASE_MODEL}@{BASE_MODEL_VERSION}")
# Out:
# Single Endpoint for Data Store, Entity Store, Customizer, Evaluator, and NIM: https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net
# Namespace: default
# Base Model for Customization: meta/llama-3.2-1b-instruct@v1.0.0+40GB

# %% [markdown]
# ### Configure Path to Prepared data

# %% [markdown]
# The following code sets the paths to the prepared dataset files.

# %%
# Path where data preparation notebook saved finetuning and evaluation data
DATA_ROOT = os.path.join(os.getcwd(), "data")
CUSTOMIZATION_DATA_ROOT = os.path.join(DATA_ROOT, "customization")
VALIDATION_DATA_ROOT = os.path.join(DATA_ROOT, "validation")
EVALUATION_DATA_ROOT = os.path.join(DATA_ROOT, "evaluation")

# Sanity checks
train_fp = f"{CUSTOMIZATION_DATA_ROOT}/training.jsonl"
assert os.path.exists(train_fp), f"The training data at '{train_fp}' does not exist. Please ensure that the data was prepared successfully."

val_fp = f"{VALIDATION_DATA_ROOT}/validation.jsonl"
assert os.path.exists(val_fp), f"The validation data at '{val_fp}' does not exist. Please ensure that the data was prepared successfully."

test_fp = f"{EVALUATION_DATA_ROOT}/xlam-test-single.jsonl"
assert os.path.exists(test_fp), f"The test data at '{test_fp}' does not exist. Please ensure that the data was prepared successfully."

# %% [markdown]
# ### Resource Organization Using Namespace
#
# You can use a [namespace](https://docs.nvidia.com/nemo/microservices/latest/manage-entities/namespaces/index.html) to isolate and organize the artifacts in this tutorial.

# %% [markdown]
# #### Create Namespace
#
# Both Data Store and Entity Store use namespaces. The following code creates namespaces for the tutorial.

# %%
def create_namespaces(nemo_client, ds_host, namespace):
    # Create namespace in Entity Store
    try:
        namespace_obj = nemo_client.namespaces.create(id=namespace)
        print(f"Created namespace in Entity Store: {namespace_obj.id}")
    except Exception as e:
        if "409" in str(e) or "422" in str(e):
            print(f"Namespace {namespace} already exists in Entity Store")
        else:
            raise e

    # Create namespace in Data Store
    nds_url = f"{ds_host}/v1/datastore/namespaces"
    resp = requests.post(nds_url, data={"namespace": namespace}, verify=False)
    assert resp.status_code in (200, 201, 409, 422), \
        f"Unexpected response from Data Store: {resp.status_code}"
    print(f"Data Store namespace creation response: {resp}")

create_namespaces(nemo_client=nemo_client, ds_host=NDS_URL, namespace=NMS_NAMESPACE)
# Out:
# HTTP Request: POST https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/namespaces "HTTP/1.1 409 Conflict"
# Retrying request to /v1/namespaces in 0.412120 seconds
# HTTP Request: POST https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/namespaces "HTTP/1.1 409 Conflict"
# Retrying request to /v1/namespaces in 0.955735 seconds
# HTTP Request: POST https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/namespaces "HTTP/1.1 409 Conflict"
# Namespace default already exists in Entity Store
# Data Store namespace creation response: <Response [409]>

# %% [markdown]
# #### Verify Namespaces
#
# The following [Data Store API](https://docs.nvidia.com/nemo/microservices/latest/api/datastore.html) and [Entity Store API](https://docs.nvidia.com/nemo/microservices/latest/api/entity-store.html) list the namespace created in the previous cell.

# %%
# Verify Namespace in Data Store (using requests as SDK doesn't cover Data Store)
response = requests.get(f"{NDS_URL}/v1/datastore/namespaces/{NMS_NAMESPACE}", verify=False)
print(f"Data Store - Status Code: {response.status_code}\nResponse JSON: {response.json()}")

# Verify Namespace in Entity Store
namespace_obj = nemo_client.namespaces.retrieve(namespace_id=NMS_NAMESPACE)
print(f"\nEntity Store - Namespace: {namespace_obj.id}")
print(f"Created at: {namespace_obj.created_at}")
print(f"Description: {namespace_obj.description}")
print(f"Project: {namespace_obj.project}")
# Out:
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/namespaces/default "HTTP/1.1 200 OK"
# Data Store - Status Code: 201
# Response JSON: {'namespace': 'default', 'created_at': '2026-04-27T04:51:05Z', 'updated_at': '2026-04-29T00:13:57Z'}
#
# Entity Store - Namespace: default
# Created at: 2026-04-24 08:50:47.119733
# Description: None
# Project: None

# %% [markdown]
# **Tips**:
# To list all available namespaces use
# ```python
# requests.get(f"{NDS_URL}/v1/datastore/namespaces/") # For Data Store
# nemo_client.namespaces.list() # For Entity Store
# ```
#
# To delete a namespace use:
# ```python
# requests.delete(f"{NDS_URL}/v1/datastore/namespaces/{namespace}") # For Data Store
# nemo_client.namespaces.delete(namespace) # For Entity Store
# ```

# %%
requests.get(f"{NDS_URL}/v1/datastore/namespaces/")
nemo_client.namespaces.list()
# Out:
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/namespaces "HTTP/1.1 200 OK"
# SyncDefaultPagination[Namespace](object='list', data=[Namespace(id='default', created_at=datetime.datetime(2026, 4, 24, 8, 50, 47, 119733), custom_fields={}, description=None, ownership=None, project=None, updated_at=datetime.datetime(2026, 4, 24, 8, 50, 47, 119735)), Namespace(id='finetuning-demos', created_at=datetime.datetime(2026, 4, 24, 13, 59, 33, 580482), custom_fields={}, description=None, ownership=None, project=None, updated_at=datetime.datetime(2026, 4, 24, 13, 59, 33, 580490))], sort='created_at', pagination=DefaultPaginationPagination(current_page_size=2, page=1, page_size=10, total_pages=1, total_results=2), filter={}, search={})

# %% [markdown]
# ---
# <a id="step-1"></a>
# ## Step 1: Upload Data to NeMo Data Store

# %% [markdown]
# The NeMo Data Store supports data management using the Hugging Face `HfApi` Client.
#
# **Note that this step does not interact with Hugging Face at all, it just uses the client library to interact with NeMo Data Store.** This is in comparison to the previous notebook, where we used the `load_dataset` API to download the xLAM dataset from Hugging Face's repository.
#
# More information can be found in [documentation](https://docs.nvidia.com/nemo/microservices/latest/manage-entities/tutorials/manage-dataset-files.html#set-up-hugging-face-client-with-nemo-data-store)

# %% [markdown]
# ### 1.1 Create Repository

# %%
repo_id = f"{NMS_NAMESPACE}/{DATASET_NAME}"

# %%
# hf_api already initialized in pcai_setup.py using internal Data Store URL
from pcai_setup import hf_api

# Create repo
hf_api.create_repo(
    repo_id=repo_id,
    repo_type='dataset',
)
# Out:
# HTTP Request: POST http://nemo-data-store.nemo-microservices-25121.svc.cluster.local:3000/v1/hf/api/repos/create "HTTP/1.1 200 OK"
# RepoUrl('datasets/default/xlam-ft-dataset-latest', endpoint='http://nemo-data-store.nemo-microservices-25121.svc.cluster.local:3000/v1/hf', repo_type='dataset', repo_id='default/xlam-ft-dataset-latest')

# %% [markdown]
# Next, creating a dataset programmatically requires two steps: uploading and registration. More information can be found in [documentation](https://docs.nvidia.com/nemo/microservices/latest/manage-entities/datasets/create-dataset.html).

# %% [markdown]
# ### 1.2 Upload Dataset Files to NeMo Data Store

# %%
hf_api.upload_file(path_or_fileobj=train_fp,
    path_in_repo="training/training.jsonl",
    repo_id=repo_id,
    repo_type='dataset',
)

hf_api.upload_file(path_or_fileobj=val_fp,
    path_in_repo="validation/validation.jsonl",
    repo_id=repo_id,
    repo_type='dataset',
)

hf_api.upload_file(path_or_fileobj=test_fp,
    path_in_repo="testing/xlam-test-single.jsonl",
    repo_id=repo_id,
    repo_type='dataset',
)
# Out:
# HTTP Request: POST http://nemo-data-store.nemo-microservices-25121.svc.cluster.local:3000/v1/hf/api/datasets/default/xlam-ft-dataset-latest/preupload/main "HTTP/1.1 200 OK"
# HTTP Request: POST http://nemo-data-store.nemo-microservices-25121.svc.cluster.local:3000/v1/hf/datasets/default/xlam-ft-dataset-latest.git/info/lfs/objects/batch "HTTP/1.1 200 OK"
# Upload 0 LFS files: 0it [00:00, ?it/s]
# HTTP Request: POST http://nemo-data-store.nemo-microservices-25121.svc.cluster.local:3000/v1/hf/api/datasets/default/xlam-ft-dataset-latest/commit/main "HTTP/1.1 200 OK"
# HTTP Request: POST http://nemo-data-store.nemo-microservices-25121.svc.cluster.local:3000/v1/hf/api/datasets/default/xlam-ft-dataset-latest/preupload/main "HTTP/1.1 200 OK"
# HTTP Request: POST http://nemo-data-store.nemo-microservices-25121.svc.cluster.local:3000/v1/hf/datasets/default/xlam-ft-dataset-latest.git/info/lfs/objects/batch "HTTP/1.1 200 OK"
# Upload 0 LFS files: 0it [00:00, ?it/s]
# HTTP Request: POST http://nemo-data-store.nemo-microservices-25121.svc.cluster.local:3000/v1/hf/api/datasets/default/xlam-ft-dataset-latest/commit/main "HTTP/1.1 200 OK"
# HTTP Request: POST http://nemo-data-store.nemo-microservices-25121.svc.cluster.local:3000/v1/hf/api/datasets/default/xlam-ft-dataset-latest/preupload/main "HTTP/1.1 200 OK"
# HTTP Request: POST http://nemo-data-store.nemo-microservices-25121.svc.cluster.local:3000/v1/hf/datasets/default/xlam-ft-dataset-latest.git/info/lfs/objects/batch "HTTP/1.1 200 OK"
# Upload 0 LFS files: 0it [00:00, ?it/s]
# HTTP Request: POST http://nemo-data-store.nemo-microservices-25121.svc.cluster.local:3000/v1/hf/api/datasets/default/xlam-ft-dataset-latest/commit/main "HTTP/1.1 200 OK"
# CommitInfo(commit_url='', commit_message='Upload testing/xlam-test-single.jsonl with huggingface_hub', commit_description='', oid='95a45d1c0b892f12f718247f36242dcbae403d75', pr_url=None, repo_url=RepoUrl('', endpoint='http://nemo-data-store.nemo-microservices-25121.svc.cluster.local:3000/v1/hf', repo_type='model', repo_id=''), pr_revision=None, pr_num=None)

# %% [markdown]
# Other tips:
# * Take a look at the `path_in_repo` argument above. If there are more than one files in the subfolders:
#     * All the .jsonl files in `training/` will be merged and used for training by customizer.
#     * All the .jsonl files in `validation/` will be merged and used for validation by customizer.
# * NeMo Data Store generally supports data management using the [HfApi API](https://huggingface.co/docs/huggingface_hub/en/package_reference/hf_api). For example, to delete a repo, you may use -
# ```python
#    hf_api.delete_repo(
#      repo_id=repo_id,
#      repo_type="dataset"
# )
# ```

# %% [markdown]
# ### 1.3 Register the Dataset with NeMo Entity Store

# %% [markdown]
# To use a dataset for operations such as evaluations and customizations, register a dataset using the `nemo_client.datasets.create()` method.
# Register the dataset to refer to it by its namespace and name afterward.

# %%
# Create dataset
dataset = nemo_client.datasets.create(
    name=DATASET_NAME,
    namespace=NMS_NAMESPACE,
    description="Tool calling xLAM dataset in OpenAI ChatCompletions format",
    files_url=f"hf://datasets/{NMS_NAMESPACE}/{DATASET_NAME}",
    project="tool_calling",
)
print(f"Created dataset: {dataset.namespace}/{dataset.name}")
dataset
# Out:
# HTTP Request: POST https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/datasets "HTTP/1.1 200 OK"
# Created dataset: default/xlam-ft-dataset-latest
# Dataset(files_url='hf://datasets/default/xlam-ft-dataset-latest', id='dataset-UkneKB9iGvajHA1n5Nvx8x', created_at=datetime.datetime(2026, 4, 29, 0, 49, 19, 239448), custom_fields={}, description='Tool calling xLAM dataset in OpenAI ChatCompletions format', format=None, hf_endpoint=None, limit=None, name='xlam-ft-dataset-latest', namespace='default', project='tool_calling', split=None, updated_at=datetime.datetime(2026, 4, 29, 0, 49, 19, 239450))

# %%
# Sanity check to validate dataset
dataset_obj = nemo_client.datasets.retrieve(namespace=NMS_NAMESPACE, dataset_name=DATASET_NAME)

print("Files URL:", dataset_obj.files_url)
assert dataset_obj.files_url == f"hf://datasets/{repo_id}"
# Out:
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/datasets/default/xlam-ft-dataset-latest "HTTP/1.1 200 OK"
# Files URL: hf://datasets/default/xlam-ft-dataset-latest

# %%
# Create new project
nemo_client.projects.create(
    name="demos",
    namespace="default",
    description="Fine-tuning demos on NeMo Microservices 25.12.1",
)
print("Project created")
# Out:
# HTTP Request: POST https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/projects "HTTP/1.1 200 OK"
# Project created

# %%
# Link the dataset
nemo_client.datasets.update(
    dataset_name="xlam-ft-dataset-latest",
    namespace="default",
    project="default/demos",
)
print("Dataset linked")
# Out:
# HTTP Request: PATCH https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/datasets/default/xlam-ft-dataset-latest "HTTP/1.1 200 OK"
# Dataset linked

# %% [markdown]
# ---
# <a id="step-2"></a>
# ## 2. LoRA Customization with NeMo Customizer

# %% [markdown]
# ### 2.1 Start the Training Job

# %% [markdown]
# Start the training job by calling `nemo_client.customization.jobs.create()` method.
# The following code sets the training parameters and starts the job.
#
# **The training job will take approximately 45 minutes to complete.**

# %%
BASE_MODEL_VERSION="v1.0.0+40GB"

# %%
CUSTOM_MODEL = f"{NMS_NAMESPACE}/llama-3.2-1b-xlam-toolcalling@latest"

# %%
# Create customization job
# If WANDB_API_KEY is set, we send it in the request header, which will report the training metrics to Weights & Biases (WandB).
if WANDB_API_KEY:
    client_with_wandb = nemo_client.with_options(default_headers={"wandb-api-key": WANDB_API_KEY})
else:
    client_with_wandb = nemo_client

customization = nemo_client.customization.jobs.create(
    name="llama-3.2-1b-xlam-ft-latest",
    output_model=CUSTOM_MODEL,
    config=f"{BASE_MODEL}@{BASE_MODEL_VERSION}",
    dataset={"name": DATASET_NAME, "namespace": NMS_NAMESPACE},
    project="default/demos",
    hyperparameters={
        "training_type": "sft",
        "finetuning_type": "lora",
        "epochs": 2,
        "batch_size": 16,
        "learning_rate": 0.0001,
        "lora": {
            "adapter_dim": 32,
            "adapter_dropout": 0.1
        }
    }
)
print(f"Created customization job: {customization.id}")
customization
# Out:
# HTTP Request: POST https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs "HTTP/1.1 200 OK"
# Created customization job: cust-Q7ZsVic1VdvyR4Z8ia7EdZ
# CustomizationJob(config='meta/llama-3.2-1b-instruct@v1.0.0+40GB', dataset='default/xlam-ft-dataset-latest', hyperparameters=Hyperparameters(finetuning_type='lora', adam_beta1=0.9, adam_beta2=0.99, batch_size=16, distillation=None, dpo=None, epochs=2, grpo=None, learning_rate=0.0001, log_every_n_steps=10, lora=LoraParameters(adapter_dim=32, adapter_dropout=0.1, alpha=16, target_modules=None), max_steps=-1, min_learning_rate=None, optimizer='adamw_with_cosine_annealing', seed=42, sequence_packing_enabled=False, sft=None, training_type='sft', val_check_interval=None, warmup_steps=200, weight_decay=None), id='cust-Q7ZsVic1VdvyR4Z8ia7EdZ', config_snapshot=CustomizationConfigJobValue(base_model='meta/llama-3.2-1b-instruct', max_seq_length=4096, precision='bf16-mixed', training_option=CustomizationTrainingOption(finetuning_type='lora', micro_batch_size=1, num_gpus=1, training_type='sft', data_parallel_size=1, expert_model_parallel_size=None, num_nodes=1, pipeline_parallel_size=1, tensor_parallel_size=1, use_sequence_parallel=False), dataset_schema=None, prompt_template='{prompt} {completion}'), created_at=datetime.datetime(2026, 4, 29, 1, 0, 30, 763778), custom_fields={}, dataset_parameters=None, description=None, integrations=None, namespace='default', output_model='default/llama-3.2-1b-xlam-toolcalling@latest', ownership=None, project='default/demos', status='created', status_details=CustomizationStatusDetails(created_at=datetime.datetime(2026, 4, 29, 1, 0, 33, 858032), status=None, updated_at=datetime.datetime(2026, 4, 29, 1, 0, 33, 858032), best_epoch=None, elapsed_time=0.0, epochs_completed=0, metrics=None, percentage_done=0.0, status_logs=[StatusLog(updated_at=datetime.datetime(2026, 4, 29, 1, 0, 33, 858032), detail=None, message='created')], steps_completed=0, steps_per_epoch=None, train_loss=None, val_loss=None), updated_at=datetime.datetime(2026, 4, 29, 1, 0, 30, 763780), warnings=None)

# %% [markdown]
# **Note**: In the snippet above, the model name and version are passed directly in the `config` argument. However, in production environments, administrators typically create customization **[targets](https://docs.nvidia.com/nemo/microservices/latest/fine-tune/manage-customization-targets/index.html)** and corresponding **[configs](https://docs.nvidia.com/nemo/microservices/latest/fine-tune/manage-customization-configs/index.html)**. This approach allows you to configure once and reuse model configurations for multiple customization jobs. In such cases, you simply reference the created configuration in the `config` argument. For more details, refer to the documentation.

# %% [markdown]
# The following code sets variables for storing the job ID and customized model name.

# %%
# To track status
JOB_ID = customization.id

customization = nemo_client.customization.jobs.retrieve(JOB_ID)

# This will be the name of the model that will be used to send inference queries to
CUSTOMIZED_MODEL = customization.output_model
# Out:
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"

# %% [markdown]
# **Tips**:
# * If you configured the NeMo Customizer microservice with your own [Weights & Biases (WandB)](https://wandb.ai/) API key, you can find the training graphs and logs in your WandB account, "nvidia-nemo-customizer" project. Your run ID is similar to your customization `JOB_ID`.
#
# * To cancel a job that you scheduled incorrectly, run the following code.
#
#   ```python
#   nemo_client.customization.jobs.cancel(job_id=JOB_ID)
#   ```

# %% [markdown]
# ### 2.2 Get Job Status
#
# Get the job status by using the `nemo_client.customization.jobs.status()` method.
# The following code sets the job ID and sends the request.

# %%
# Get job status
job_status = nemo_client.customization.jobs.status(job_id=JOB_ID)

print("Percentage done:", job_status.percentage_done)
print("Job Status:", json.dumps(job_status.model_dump(), indent=2, default=str))
# Out:
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ/status "HTTP/1.1 200 OK"
# Percentage done: 100.0
# Job Status: {
#   "created_at": "2026-04-29 01:00:33.858032",
#   "status": "completed",
#   "updated_at": "2026-04-29 01:17:43.211828",
#   "best_epoch": 1,
#   "elapsed_time": 0.0,
#   "epochs_completed": 2,
#   "metrics": {
#     "keys": [
#       "train_loss",
#       "val_loss"
#     ],
#     "metrics": {
#       "train_accuracy": [],
#       "train_loss": [
#         {
#           "step": 9,
#           "timestamp": "2026-04-29T01:07:47.024209",
#           "value": 1.7528048753738403
#         },
#         {
#           "step": 19,
#           "timestamp": "2026-04-29T01:07:58.458299",
#           "value": 1.239764928817749
#         },
#         {
#           "step": 29,
#           "timestamp": "2026-04-29T01:08:10.088810",
#           "value": 0.5186103582382202
#         },
#         {
#           "step": 39,
#           "timestamp": "2026-04-29T01:08:21.862467",
#           "value": 0.1260678768157959
#         },
#         {
#           "step": 49,
#           "timestamp": "2026-04-29T01:08:33.736315",
#           "value": 0.20616231858730316
#         },
#         {
#           "step": 59,
#           "timestamp": "2026-04-29T01:08:44.921020",
#           "value": 0.08065932244062424
#         },
#         {
#           "step": 69,
#           "timestamp": "2026-04-29T01:08:56.101147",
#           "value": 0.09559006989002228
#         },
#         {
#           "step": 79,
#           "timestamp": "2026-04-29T01:09:07.472711",
#           "value": 0.023905809968709946
#         },
#         {
#           "step": 89,
#           "timestamp": "2026-04-29T01:09:19.032937",
#           "value": 0.08563369512557983
#         },
#         {
#           "step": 99,
#           "timestamp": "2026-04-29T01:09:30.491182",
#           "value": 0.07989886403083801
#         },
#         {
#           "step": 109,
#           "timestamp": "2026-04-29T01:09:41.982303",
#           "value": 0.11857045441865921
#         },
#         {
#           "step": 119,
#           "timestamp": "2026-04-29T01:09:53.797789",
#           "value": 0.0997641533613205
#         },
#         {
#           "step": 129,
#           "timestamp": "2026-04-29T01:10:05.632725",
#           "value": 0.04439043253660202
#         },
#         {
#           "step": 139,
#           "timestamp": "2026-04-29T01:10:17.101334",
#           "value": 0.056476619094610214
#         },
#         {
#           "step": 149,
#           "timestamp": "2026-04-29T01:10:28.922920",
#           "value": 0.09975821524858475
#         },
#         {
#           "step": 159,
#           "timestamp": "2026-04-29T01:10:40.256988",
#           "value": 0.08293664455413818
#         },
#         {
#           "step": 169,
#           "timestamp": "2026-04-29T01:10:51.998076",
#           "value": 0.054411254823207855
#         },
#         {
#           "step": 179,
#           "timestamp": "2026-04-29T01:11:03.518895",
#           "value": 0.06710273772478104
#         },
#         {
#           "step": 189,
#           "timestamp": "2026-04-29T01:11:15.495458",
#           "value": 0.11996756494045258
#         },
#         {
#           "step": 199,
#           "timestamp": "2026-04-29T01:11:26.954346",
#           "value": 0.027495913207530975
#         },
#         {
#           "step": 209,
#           "timestamp": "2026-04-29T01:11:39.023855",
#           "value": 0.02602917142212391
#         },
#         {
#           "step": 219,
#           "timestamp": "2026-04-29T01:12:55.595172",
#           "value": 0.09002573788166046
#         },
#         {
#           "step": 229,
#           "timestamp": "2026-04-29T01:13:06.863017",
#           "value": 0.08220846951007843
#         },
#         {
#           "step": 239,
#           "timestamp": "2026-04-29T01:13:18.356796",
#           "value": 0.10907416045665741
#         },
#         {
#           "step": 249,
#           "timestamp": "2026-04-29T01:13:30.496744",
#           "value": 0.020704450085759163
#         },
#         {
#           "step": 259,
#           "timestamp": "2026-04-29T01:13:41.923414",
#           "value": 0.058190856128931046
#         },
#         {
#           "step": 269,
#           "timestamp": "2026-04-29T01:13:53.854660",
#           "value": 0.05282256007194519
#         },
#         {
#           "step": 279,
#           "timestamp": "2026-04-29T01:14:05.353519",
#           "value": 0.012069725431501865
#         },
#         {
#           "step": 289,
#           "timestamp": "2026-04-29T01:14:17.532492",
#           "value": 0.06336025893688202
#         },
#         {
#           "step": 299,
#           "timestamp": "2026-04-29T01:14:29.435252",
#           "value": 0.04544456675648689
#         },
#         {
#           "step": 309,
#           "timestamp": "2026-04-29T01:14:40.730059",
#           "value": 0.027799779549241066
#         },
#         {
#           "step": 319,
#           "timestamp": "2026-04-29T01:14:51.961830",
#           "value": 0.05023078992962837
#         },
#         {
#           "step": 329,
#           "timestamp": "2026-04-29T01:15:04.438132",
#           "value": 0.08108173310756683
#         },
#         {
#           "step": 339,
#           "timestamp": "2026-04-29T01:15:16.723310",
#           "value": 0.013917416334152222
#         },
#         {
#           "step": 349,
#           "timestamp": "2026-04-29T01:15:28.414644",
#           "value": 0.008749146945774555
#         },
#         {
#           "step": 359,
#           "timestamp": "2026-04-29T01:15:39.647382",
#           "value": 0.008883732371032238
#         },
#         {
#           "step": 369,
#           "timestamp": "2026-04-29T01:15:52.251726",
#           "value": 0.008191050961613655
#         },
#         {
#           "step": 379,
#           "timestamp": "2026-04-29T01:16:03.832901",
#           "value": 0.03127051144838333
#         },
#         {
#           "step": 389,
#           "timestamp": "2026-04-29T01:16:15.681533",
#           "value": 0.011664223857223988
#         },
#         {
#           "step": 399,
#           "timestamp": "2026-04-29T01:16:27.944279",
#           "value": 0.02846747636795044
#         },
#         {
#           "step": 409,
#           "timestamp": "2026-04-29T01:16:39.354017",
#           "value": 0.040655024349689484
#         },
#         {
#           "step": 419,
#           "timestamp": "2026-04-29T01:16:51.253407",
#           "value": 0.03245926648378372
#         },
#         {
#           "step": 429,
#           "timestamp": "2026-04-29T01:17:02.546306",
#           "value": 0.021203985437750816
#         }
#       ],
#       "val_accuracy": [],
#       "val_loss": [
#         {
#           "step": 217,
#           "timestamp": "2026-04-29T01:12:20.992797",
#           "value": 0.056556615978479385
#         },
#         {
#           "step": 435,
#           "timestamp": "2026-04-29T01:17:39.608933",
#           "value": 0.04958243668079376
#         }
#       ]
#     }
#   },
#   "percentage_done": 100.0,
#   "status_logs": [
#     {
#       "updated_at": "2026-04-29 01:00:33",
#       "detail": null,
#       "message": "PVCCreated"
#     },
#     {
#       "updated_at": "2026-04-29 01:00:33.858032",
#       "detail": null,
#       "message": "created"
#     },
#     {
#       "updated_at": "2026-04-29 01:00:33.858032",
#       "detail": "The training job is pending",
#       "message": "TrainingJobPending"
#     },
#     {
#       "updated_at": "2026-04-29 01:00:36",
#       "detail": null,
#       "message": "EntityHandler_0_Created"
#     },
#     {
#       "updated_at": "2026-04-29 01:00:36",
#       "detail": null,
#       "message": "EntityHandler_0_Running"
#     },
#     {
#       "updated_at": "2026-04-29 01:00:41",
#       "detail": null,
#       "message": "container in pod cust-q7zsvic1vdvyr4z8ia7edz-entity-handler-0-7n7bk is waiting because ContainerCreating: None"
#     },
#     {
#       "updated_at": "2026-04-29 01:00:58",
#       "detail": null,
#       "message": "EntityHandler_0_Pending"
#     },
#     {
#       "updated_at": "2026-04-29 01:00:58",
#       "detail": null,
#       "message": "EntityHandler_0_Completed"
#     },
#     {
#       "updated_at": "2026-04-29 01:00:58",
#       "detail": null,
#       "message": "TrainingJobCreated"
#     },
#     {
#       "updated_at": "2026-04-29 01:00:58",
#       "detail": null,
#       "message": "TrainingJobPending"
#     },
#     {
#       "updated_at": "2026-04-29 01:01:58",
#       "detail": null,
#       "message": "NotEnoughResources"
#     },
#     {
#       "updated_at": "2026-04-29 01:05:00",
#       "detail": null,
#       "message": "TrainingJobPending"
#     },
#     {
#       "updated_at": "2026-04-29 01:05:01",
#       "detail": null,
#       "message": "container in pod cust-q7zsvic1vdvyr4z8ia7edz-training-job-worker-0 is waiting because ContainerCreating: None"
#     },
#     {
#       "updated_at": "2026-04-29 01:05:10",
#       "detail": null,
#       "message": "TrainingJobRunning"
#     },
#     {
#       "updated_at": "2026-04-29 01:18:10",
#       "detail": null,
#       "message": "TrainingJobCompleted"
#     },
#     {
#       "updated_at": "2026-04-29 01:18:13",
#       "detail": null,
#       "message": "EntityHandler_1_Created"
#     },
#     {
#       "updated_at": "2026-04-29 01:18:13",
#       "detail": null,
#       "message": "EntityHandler_1_Running"
#     },
#     {
#       "updated_at": "2026-04-29 01:18:13",
#       "detail": null,
#       "message": "container in pod cust-q7zsvic1vdvyr4z8ia7edz-entity-handler-1-c6s2n is waiting because ContainerCreating: None"
#     },
#     {
#       "updated_at": "2026-04-29 01:18:28",
#       "detail": null,
#       "message": "EntityHandler_1_Pending"
#     },
#     {
#       "updated_at": "2026-04-29 01:18:28",
#       "detail": null,
#       "message": "EntityHandler_1_Completed"
#     }
#   ],
#   "steps_completed": 438,
#   "steps_per_epoch": 219,
#   "train_loss": 0.008191050961613655,
#   "val_loss": 0.04958243668079376
# }

# %%
# Add wait job function to wait for the customization job to complete

from time import sleep, time

def wait_job(nemo_client, job_id: str, polling_interval: int = 10, timeout: int = 6000):
    """Helper for waiting an eval job using SDK."""
    start_time = time()
    job = nemo_client.customization.jobs.retrieve(job_id=job_id)
    status = job.status

    while (status in ["pending", "created", "running"]):
        # Check for timeout
        if time() - start_time > timeout:
            raise RuntimeError(f"Took more than {timeout} seconds.")

        # Sleep before polling again
        sleep(polling_interval)

        # Fetch updated status and progress
        job = nemo_client.customization.jobs.retrieve(job_id=job_id)
        status = job.status
        progress = 0.0
        if status == "running" and job.status_details:
            progress = job.status_details.percentage_done or 0.0
        elif status == "completed":
            progress = 100

        print(f"Job status: {status} after {time() - start_time:.2f} seconds. Progress: {progress}%")


    return job

job = wait_job(nemo_client, JOB_ID, polling_interval=5, timeout=2400)

# Wait for 2 minutes, because sometimes, the job is finished, but the finetuned model is not ready in NIM yet.
sleep(120)
# Out:
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 5.14 seconds. Progress: 0.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 10.19 seconds. Progress: 0.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 15.21 seconds. Progress: 0.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 20.23 seconds. Progress: 0.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 25.31 seconds. Progress: 0.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 30.40 seconds. Progress: 0.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 35.42 seconds. Progress: 0.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 40.47 seconds. Progress: 0.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 45.51 seconds. Progress: 0.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 50.56 seconds. Progress: 0.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 503 Service Unavailable"
# Retrying request to /v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ in 0.497472 seconds
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 56.13 seconds. Progress: 0.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 61.19 seconds. Progress: 0.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 66.21 seconds. Progress: 0.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 71.27 seconds. Progress: 0.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 76.29 seconds. Progress: 0.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 81.31 seconds. Progress: 0.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 86.45 seconds. Progress: 0.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 91.54 seconds. Progress: 0.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 96.56 seconds. Progress: 0.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 101.58 seconds. Progress: 0.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 106.61 seconds. Progress: 0.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 111.68 seconds. Progress: 0.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 116.69 seconds. Progress: 0.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 121.73 seconds. Progress: 0.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 126.75 seconds. Progress: 0.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 131.77 seconds. Progress: 0.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 136.86 seconds. Progress: 0.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 141.92 seconds. Progress: 0.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 147.00 seconds. Progress: 0.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 152.02 seconds. Progress: 0.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 157.06 seconds. Progress: 0.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 162.14 seconds. Progress: 0.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 167.20 seconds. Progress: 0.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 172.27 seconds. Progress: 0.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 177.32 seconds. Progress: 0.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 182.38 seconds. Progress: 0.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 187.45 seconds. Progress: 0.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 192.48 seconds. Progress: 0.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 197.52 seconds. Progress: 0.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 202.60 seconds. Progress: 0.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 207.64 seconds. Progress: 0.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 212.70 seconds. Progress: 0.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 217.79 seconds. Progress: 0.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 222.92 seconds. Progress: 0.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 227.94 seconds. Progress: 0.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 232.96 seconds. Progress: 0.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 238.05 seconds. Progress: 0.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 243.07 seconds. Progress: 0.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 248.10 seconds. Progress: 0.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 253.12 seconds. Progress: 0.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 258.19 seconds. Progress: 0.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 263.23 seconds. Progress: 0.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 268.28 seconds. Progress: 0.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 273.31 seconds. Progress: 0.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 278.32 seconds. Progress: 0.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 283.34 seconds. Progress: 0.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 288.36 seconds. Progress: 0.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 293.40 seconds. Progress: 0.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 298.47 seconds. Progress: 0.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 303.49 seconds. Progress: 0.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 308.52 seconds. Progress: 0.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 313.62 seconds. Progress: 0.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 318.84 seconds. Progress: 0.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 323.86 seconds. Progress: 0.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 328.88 seconds. Progress: 0.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 333.93 seconds. Progress: 0.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 338.95 seconds. Progress: 0.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 343.96 seconds. Progress: 0.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 349.01 seconds. Progress: 0.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 354.13 seconds. Progress: 0.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 359.28 seconds. Progress: 0.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 364.31 seconds. Progress: 0.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 369.46 seconds. Progress: 0.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 374.52 seconds. Progress: 0.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 379.60 seconds. Progress: 0.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 384.66 seconds. Progress: 0.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 389.68 seconds. Progress: 0.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 394.69 seconds. Progress: 0.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 399.71 seconds. Progress: 0.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 404.79 seconds. Progress: 0.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 409.89 seconds. Progress: 0.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 414.97 seconds. Progress: 0.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 420.04 seconds. Progress: 0.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 425.07 seconds. Progress: 0.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 430.18 seconds. Progress: 0.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 435.27 seconds. Progress: 0.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 440.30 seconds. Progress: 0.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 445.36 seconds. Progress: 0.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 450.53 seconds. Progress: 0.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 455.64 seconds. Progress: 0.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 460.80 seconds. Progress: 0.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 465.87 seconds. Progress: 0.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 470.91 seconds. Progress: 0.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 475.96 seconds. Progress: 0.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 481.03 seconds. Progress: 0.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 486.11 seconds. Progress: 0.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 491.15 seconds. Progress: 0.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 496.18 seconds. Progress: 0.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 501.22 seconds. Progress: 0.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 506.25 seconds. Progress: 22.83%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 511.27 seconds. Progress: 22.83%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 516.31 seconds. Progress: 22.83%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 521.38 seconds. Progress: 22.83%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 526.42 seconds. Progress: 22.83%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 531.48 seconds. Progress: 22.83%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 536.64 seconds. Progress: 22.83%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 541.67 seconds. Progress: 22.83%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 546.72 seconds. Progress: 22.83%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 551.89 seconds. Progress: 22.83%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 556.92 seconds. Progress: 22.83%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 562.08 seconds. Progress: 22.83%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 567.18 seconds. Progress: 22.83%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 572.32 seconds. Progress: 22.83%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 577.41 seconds. Progress: 22.83%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 582.45 seconds. Progress: 22.83%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 587.49 seconds. Progress: 22.83%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 592.58 seconds. Progress: 22.83%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 597.60 seconds. Progress: 22.83%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 602.75 seconds. Progress: 22.83%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 607.86 seconds. Progress: 22.83%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 612.95 seconds. Progress: 22.83%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 618.12 seconds. Progress: 45.66%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 623.21 seconds. Progress: 45.66%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 628.36 seconds. Progress: 45.66%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 633.40 seconds. Progress: 45.66%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 638.55 seconds. Progress: 45.66%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 643.65 seconds. Progress: 45.66%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 648.67 seconds. Progress: 45.66%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 653.75 seconds. Progress: 45.66%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 658.83 seconds. Progress: 45.66%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 663.92 seconds. Progress: 45.66%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 668.95 seconds. Progress: 45.66%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 673.98 seconds. Progress: 49.77%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 679.05 seconds. Progress: 49.77%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 684.07 seconds. Progress: 49.77%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 689.14 seconds. Progress: 49.77%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 694.27 seconds. Progress: 49.77%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 699.35 seconds. Progress: 49.77%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 704.37 seconds. Progress: 49.77%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 709.42 seconds. Progress: 50.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 714.50 seconds. Progress: 50.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 719.58 seconds. Progress: 50.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 724.66 seconds. Progress: 50.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 729.77 seconds. Progress: 50.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 734.81 seconds. Progress: 50.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 739.90 seconds. Progress: 50.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 745.07 seconds. Progress: 50.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 750.12 seconds. Progress: 50.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 755.15 seconds. Progress: 50.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 760.22 seconds. Progress: 50.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 765.28 seconds. Progress: 50.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 770.32 seconds. Progress: 50.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 775.36 seconds. Progress: 50.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 780.50 seconds. Progress: 50.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 785.58 seconds. Progress: 50.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 790.63 seconds. Progress: 50.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 795.65 seconds. Progress: 50.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 800.68 seconds. Progress: 68.49%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 805.77 seconds. Progress: 68.49%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 810.81 seconds. Progress: 68.49%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 815.89 seconds. Progress: 68.49%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 820.97 seconds. Progress: 68.49%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 826.02 seconds. Progress: 68.49%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 831.04 seconds. Progress: 68.49%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 836.17 seconds. Progress: 68.49%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 841.27 seconds. Progress: 68.49%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 846.30 seconds. Progress: 68.49%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 851.36 seconds. Progress: 68.49%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 856.43 seconds. Progress: 68.49%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 861.54 seconds. Progress: 68.49%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 866.64 seconds. Progress: 68.49%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 871.74 seconds. Progress: 68.49%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 876.77 seconds. Progress: 68.49%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 881.89 seconds. Progress: 68.49%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 886.97 seconds. Progress: 68.49%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 892.01 seconds. Progress: 68.49%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 897.07 seconds. Progress: 68.49%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 902.15 seconds. Progress: 68.49%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 907.20 seconds. Progress: 68.49%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 912.24 seconds. Progress: 68.49%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 917.27 seconds. Progress: 68.49%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 922.31 seconds. Progress: 91.32%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 927.38 seconds. Progress: 91.32%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 932.47 seconds. Progress: 91.32%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 937.50 seconds. Progress: 91.32%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 942.56 seconds. Progress: 91.32%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 947.71 seconds. Progress: 91.32%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 952.79 seconds. Progress: 91.32%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 957.86 seconds. Progress: 91.32%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 962.90 seconds. Progress: 91.32%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 967.93 seconds. Progress: 91.32%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 973.03 seconds. Progress: 91.32%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 978.16 seconds. Progress: 91.32%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 983.22 seconds. Progress: 91.32%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 988.24 seconds. Progress: 91.32%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 993.32 seconds. Progress: 99.54%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 998.37 seconds. Progress: 100.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 1003.44 seconds. Progress: 100.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 1008.46 seconds. Progress: 100.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 1013.54 seconds. Progress: 100.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 1018.61 seconds. Progress: 100.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 1023.66 seconds. Progress: 100.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 1028.84 seconds. Progress: 100.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 1033.91 seconds. Progress: 100.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: running after 1038.93 seconds. Progress: 100.0%
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/customization/jobs/cust-Q7ZsVic1VdvyR4Z8ia7EdZ "HTTP/1.1 200 OK"
# Job status: completed after 1043.95 seconds. Progress: 100%

# %% [markdown]
# **IMPORTANT:** At this point, the customization job should be completed. If waiting for the job to finish failed or the status is not `"completed"`, please check the logs (`job.status_details.status_logs`).

# %% [markdown]
# ### 2.3 Validate Availability of Custom Model
# The following NeMo Entity Store API should display the model when the training job is complete.
# The list below shows all models filtered by your namespace and sorted by the latest first.
# For more information about this API, see the [NeMo Entity Store API reference](https://docs.nvidia.com/nemo/microservices/latest/api/entity-store.html).
# With the following code, you can find all customized models, including the one trained in the previous cells.
# Look for the `name` fields in the output, which should match your `CUSTOMIZED_MODEL`.

# %%
# List models with filters
models_page = nemo_client.models.list(
    filter={"namespace": NMS_NAMESPACE},
    sort="-created_at"
)

# Print models information
print(f"Found {len(models_page.data)} models in namespace {NMS_NAMESPACE}:")
for model in models_page.data:
    print(f"\nModel: {model.name}")
    print(f"  Namespace: {model.namespace}")
    print(f"  Base Model: {model.base_model}")
    print(f"  Created: {model.created_at}")
    if model.peft:
        print(f"  Fine-tuning Type: {model.peft.finetuning_type}")
# Out:
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/models?filter%5Bnamespace%5D=default&sort=-created_at "HTTP/1.1 200 OK"
# Found 1 models in namespace default:
#
# Model: llama-3.2-1b-xlam-toolcalling@latest
#   Namespace: default
#   Base Model: meta/llama-3.2-1b-instruct
#   Created: 2026-04-29 01:00:33.899466
#   Fine-tuning Type: lora

# %% [markdown]
#  The customized model can also be retrieved directly by using its name.

# %%
# CUSTOMIZED_MODEL is constructed as `namespace/model_name`, so we need to extract the model name
model = nemo_client.models.retrieve(namespace=NMS_NAMESPACE, model_name=CUSTOMIZED_MODEL.split("/")[1])

print(f"Model: {model.namespace}/{model.name}")
print(f"Base Model: {model.base_model}")
print(f"Status: {model.artifact.status}")
# Out:
# HTTP Request: GET https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/models/default/llama-3.2-1b-xlam-toolcalling@latest "HTTP/1.1 200 OK"
# Model: default/llama-3.2-1b-xlam-toolcalling@latest
# Base Model: meta/llama-3.2-1b-instruct
# Status: upload_completed

# %% [markdown]
# NVIDIA NIM directly picks up the LoRA adapters from NeMo Entity Store. You can also query the NIM endpoint to look for it, as shown in the following code.

# %%
# Check if the custom LoRA model is hosted by NVIDIA NIM
# List NIM models via external Istio endpoint
import requests
resp = requests.get(f"{NEMO_URL}/v1/models/nim", verify=False)
nim_models = resp.json()
print("NIM models (inference-ready):")
for m in nim_models["data"]:
    print(f"  {m['id']}")

# Verify fine-tuned model is available
model_ids = [m["id"] for m in nim_models["data"]]
assert CUSTOM_MODEL in model_ids, f"Model {CUSTOM_MODEL} not found in NIM"
print(f"\n Fine-tuned model {CUSTOM_MODEL} is ready for inference")
# Out:
# NIM models (inference-ready):
#   meta/llama-3.2-1b-instruct
#   finetuning-demos/llama-3.2-1b-xlam-toolcalling@v2
#   finetuning-demos/llama-3.2-1b-xlam-toolcalling@v3
#   default/llama-3.2-1b-xlam-toolcalling@latest
#
#  Fine-tuned model default/llama-3.2-1b-xlam-toolcalling@latest is ready for inference

# %% [markdown]
# ---
#
# <a id="step-3"></a>
# ## Step 3: Sanity Test the Customized Model By Running Sample Inference
#
# Once the model is customized, its adapter is automatically saved in NeMo Entity Store and is ready to be picked up by NVIDIA NIM.
# You can test the model by sending a prompt to its NIM endpoint.
#
# First, choose one of the examples from the test set.

# %% [markdown]
# ### 3.1 Get Test Data Sample

# %%
def read_jsonl(file_path):
    """Reads a JSON Lines file and yields parsed JSON objects"""
    with open(file_path, 'r', encoding='utf-8') as file:
        for line in file:
            line = line.strip()  # Remove leading/trailing whitespace
            if not line:
                continue  # Skip empty lines
            try:
                yield json.loads(line)
            except json.JSONDecodeError as e:
                print(f"Error decoding JSON: {e}")
                continue


test_data = list(read_jsonl(test_fp))

print(f"There are {len(test_data)} examples in the test set")
# Out:
# There are 713 examples in the test set

# %%
# Randomly choose
test_sample = random.choice(test_data)

# Visualize the inputs to the LLM - user query and available tools
test_sample['messages'], test_sample['tools']
# Out:
# ([{'role': 'user',
#    'content': 'What is the area of a circle with a radius of 0.5 units?'}],
#  [{'type': 'function',
#    'function': {'name': 'circle_area',
#     'description': 'Computes the area of a circle given its radius.',
#     'parameters': {'type': 'object',
#      'properties': {'radius': {'description': 'The radius of the circle.',
#        'type': 'number'}}}}},
#   {'type': 'function',
#    'function': {'name': 'calculate_distance',
#     'description': 'Calculates the Euclidean distance between two points in n-dimensional space.',
#     'parameters': {'type': 'object',
#      'properties': {'point1': {'description': 'The coordinates of the first point.',
#        'type': 'array'},
#       'point2': {'description': 'The coordinates of the second point.',
#        'type': 'array'}}}}},
#   {'type': 'function',
#    'function': {'name': 'can_attend_all_meetings',
#     'description': 'Determines if a person can attend all meetings given a list of meeting time intervals.',
#     'parameters': {'type': 'object',
#      'properties': {'intervals': {'description': 'A list of meeting time intervals, where each interval is represented as [start_time, end_time].',
#        'type': 'array'}}}}}])

# %% [markdown]
# ### 3.2 Send an Inference Call to NIM
#
# NIM exposes an OpenAI-compatible completions API endpoint, which you can query using the `OpenAI` client library as shown in the following code.

# %%
inference_client = OpenAI(
  base_url = f"{NIM_URL}/v1",
  api_key = "None"
)

completion = inference_client.chat.completions.create(
  model = CUSTOMIZED_MODEL,
  messages = test_sample["messages"],
  tools = test_sample["tools"],
  tool_choice = 'auto',
  temperature = 0.1,
  top_p = 0.7,
  max_tokens = 512,
  stream = False
)

completion.choices[0].message.tool_calls
# Out:
# HTTP Request: POST https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/chat/completions "HTTP/1.1 200 OK"
# [ChatCompletionMessageFunctionToolCall(id='chatcmpl-tool-385822bf4b8b47fea3d1614ab786e680', function=Function(arguments='{"radius": 0.5}', name='circle_area'), type='function')]

# %% [markdown]
# The Python SDK also supports the same inference call, as shown in the following code.

# %%
completion = nemo_client.chat.completions.create(
  model = CUSTOMIZED_MODEL,
  messages = test_sample["messages"],
  tools = test_sample["tools"],
  tool_choice = 'auto',
  temperature = 0.1,
  top_p = 0.7,
  max_tokens = 512,
  stream = False
)

completion.choices[0].message.tool_calls
# Out:
# HTTP Request: POST https://nemo-microservices-25121.ai-application.pcai0209.tr7.hpecolo.net/v1/chat/completions "HTTP/1.1 200 OK"
# [ChatCompletionMessageToolCall(id='chatcmpl-tool-e3ca4dea07514db0bf74748521174740', function=Function(arguments='{"radius": 0.5}', name='circle_area'), type='function')]

# %% [markdown]
# Given that the fine-tuning job was successful, you can get an inference result comparable to the ground truth:

# %%
# The ground truth answer
test_sample['tool_calls']
# Out:
# [{'type': 'function',
#   'function': {'name': 'circle_area', 'arguments': {'radius': 0.5}}}]

# %% [markdown]
# **Note:** In production environments, application developers typically provide their own set of tools relevant to the specific task. The model must select from these tools based on the given query. To explore this further, you can sample a data point from the dataset to see which tools are available, then experiment by constructing a query and observing the model’s response.

# %% [markdown]
# ### 3.3 Take Note of Your Custom Model Name
#
# Take note of your custom model name, as you will use it to run evaluations in the subsequent notebook.

# %%
print(f"Name of your custom model is: {CUSTOMIZED_MODEL}")
# Out:
# Name of your custom model is: default/llama-3.2-1b-xlam-toolcalling@latest
