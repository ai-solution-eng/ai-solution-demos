# %%
import psycopg
import pandas as pd

# %%
host='postgresql.postgresql.svc.cluster.local'
dbname='stapp'
user = 'stapp'
password = 'stapp123'
port = '5432'

# %%
conn = psycopg.connect(
    f"host={host} dbname={dbname} user={user} password={password} port={port}"
)

# %%
table_name = 'tickets'
df = pd.read_sql(f'select * from {table_name} limit 10',con=conn)
# Out:
# /tmp/ipykernel_11256/1761788050.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(f'select * from {table_name} limit 10',con=conn)

# %%
df
# Out:
#                                   ticketList_subject  \
# 0  LINK TechnoSoft Solutions 100 MBPS SERVICE REQ...
# 1  LINK Digital Dynamics Inc 547 MBPS SERVICE REQ...
# 2        LINK ACME Corp Ltd 734 MBPS SERVICE REQUEST
# 3  LINK Digital Dynamics Inc 778 MBPS SERVICE REQ...
# 4  LINK TechnoSoft Solutions 487 MBPS SERVICE REQ...
# 5        LINK ACME Corp Ltd 659 MBPS SERVICE REQUEST
# 6  LINK Enterprise Systems Co 170 MBPS SERVICE RE...
# 7  LINK Global Networks Ltd 525 MBPS SERVICE REQUEST
# 8  LINK Global Networks Ltd 391 MBPS SERVICE REQUEST
# 9  LINK Digital Dynamics Inc 586 MBPS SERVICE REQ...
#
#      ticketList_detailproblem ticketList_source_cause  \
# 0  SERVICE REQUEST LIMITATION     FIBER OPTIC PROBLEM
# 1      No Problem at MTI side         SERVICE REQUEST
# 2      No Problem at MTI side         SERVICE REQUEST
# 3  SERVICE REQUEST LIMITATION         SERVICE REQUEST
# 4         Link back to normal       EQUIPMENT PROBLEM
# 5         Link back to normal         SERVICE REQUEST
# 6         Link back to normal         SERVICE REQUEST
# 7         Link back to normal       EQUIPMENT PROBLEM
# 8      No Problem at MTI side         SERVICE REQUEST
# 9  SERVICE REQUEST LIMITATION         SERVICE REQUEST
#
#   ticketList_product_category ticketList_downtime  \
# 0                    NON GPON    04/15/2024 02:45
# 1                        GPON    03/29/2024 00:35
# 2                        GPON    04/12/2024 14:36
# 3                        GPON    04/09/2024 19:11
# 4                    NON GPON    04/08/2024 16:35
# 5                    NON GPON    04/06/2024 09:22
# 6                    NON GPON    03/31/2024 21:36
# 7                    NON GPON    04/07/2024 14:31
# 8                    NON GPON    03/21/2024 11:06
# 9                        GPON    04/03/2024 14:25
#
#                            ticketList_resolution  ticketList_mttrall
# 0  Service restored after technical intervention               30.01
# 1  Service restored after technical intervention              376.74
# 2  Service restored after technical intervention              331.04
# 3  Service restored after technical intervention              231.57
# 4  Service restored after technical intervention              111.06
# 5  Service restored after technical intervention              493.17
# 6  Service restored after technical intervention              399.17
# 7  Service restored after technical intervention              472.78
# 8  Service restored after technical intervention              153.48
# 9  Service restored after technical intervention              177.65
